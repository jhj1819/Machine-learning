# %% [markdown]
# <a href="https://colab.research.google.com/github/jhj1819/Machine-learning/blob/main/Matplotlib1023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
if 'google.colab' in sys.modules: !sudo apt-get -qq -y install fonts-nanum
 import matplotlib.font_manager as fm
 font_files = fm.findSystemFonts(fontpaths=['/usr/share/fonts/truetype/nanum']) for fpath in font_files: fm.fontManager.addfont(fpath)
import matplotlib
matplotlib.rc('font', family='NanumBarunGothic')
matplotlib.rcParams['axes.unicode_minus'] = False
# Out:
#   File "<ipython-input-3-5d0fed1fd505>", line 2
#     if 'google.colab' in sys.modules: !sudo apt-get -qq -y install fonts-nanum
#                                       ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
x = np.linspace(0,10,100)

# %%
plt.plot(x, np.sin(x), linestyle = 'solid', color = 'red', label ='sin(x)')
plt.ylim(-1.2, 1.2)
plt.legend() # 범례보기...

# %%
plt.plot(np.random.randint(1,21,20), np.random.randint(1,50,20), 's') # 뒤에 's' 안붙이면 선으로...

# %%
# 또는 scatter 써도된다

# %%
# 히스토그램
data = np.random.rand(1000)
plt.hist(data)
# Out:
# (array([112.,  95., 105., 105.,  94., 104.,  89., 104.,  96.,  96.]),
#  array([6.13410923e-04, 1.00384182e-01, 2.00154953e-01, 2.99925724e-01,
#         3.99696495e-01, 4.99467265e-01, 5.99238036e-01, 6.99008807e-01,
#         7.98779578e-01, 8.98550349e-01, 9.98321120e-01]),
#  <BarContainer object of 10 artists>)

# %%
series = pd.Series([0.3, 0.7, 0.2], index = ['a1', 'a2', 'a3'])
series
# Out:
# a1    0.3
# a2    0.7
# a3    0.2
# dtype: float64

# %%
series
# Out:
# a1    0.3
# a2    0.7
# a3    0.2
# dtype: float64

# %%
np.random.seed(0)
scores = pd.DataFrame(np.random.randint(100, size=(5,2)), columns=['mid','final'], index=[1,3,9,6,5])
print(scores)
# Out:
#    mid  final
# 1   44     47
# 3   64     67
# 9   67      9
# 6   83     21
# 5   36     87

# %%
df = pd.DataFrame(np.random.randint(0, 101, size=(5,2)), columns = ['mid', 'final'])
df
# Out:
#    mid  final
# 0   70     88
# 1   88     12
# 2   58     65
# 3   39     87
# 4   46     88

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.columns
# Out:
# Index(['mid', 'final'], dtype='object')

# %%
df.values
# Out:
# array([[70, 88],
#        [88, 12],
#        [58, 65],
#        [39, 87],
#        [46, 88]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mid     5 non-null      int64
#  1   final   5 non-null      int64
# dtypes: int64(2)
# memory usage: 208.0 bytes

# %%
df.describe()
# Out:
#              mid      final
# count   5.000000   5.000000
# mean   60.200000  68.000000
# std    19.524344  32.810059
# min    39.000000  12.000000
# 25%    46.000000  65.000000
# 50%    58.000000  87.000000
# 75%    70.000000  88.000000
# max    88.000000  88.000000

# %%
df.iloc[0]
# Out:
# mid      70
# final    88
# Name: 0, dtype: int64

# %%
df.loc[0]
# Out:
# mid      70
# final    88
# Name: 0, dtype: int64

# %%
df.loc[:,'mid']
# Out:
# 0    70
# 1    88
# 2    58
# 3    39
# 4    46
# Name: mid, dtype: int64

# %%
df.loc[:9]
# Out:
#    mid  final
# 0   70     88
# 1   88     12
# 2   58     65
# 3   39     87
# 4   46     88

# %%
df.loc[0]
# Out:
# mid      70
# final    88
# Name: 0, dtype: int64

# %%
df.iloc['mid']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-3d939d83bb36> in <cell line: 1>()
# ----> 1 df.iloc['mid']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1747             key = item_from_zerodim(key)
#    1748             if not is_integer(key):
# -> 1749                 raise TypeError("Cannot index by location index with a non-integer key")
#    1750
#    1751             # validate the location
#
# ...

# %%
df['total'] = df['mid'] + df['final']

# %%
df.drop('total',axis = 1)
# Out:
#    mid  final
# 0   70     88
# 1   88     12
# 2   58     65
# 3   39     87
# 4   46     88

# %%
df
# Out:
#    mid  final  total
# 0   70     88    158
# 1   88     12    100
# 2   58     65    123
# 3   39     87    126
# 4   46     88    134

# %%
del df['total']

# %%
df
# Out:
#    mid  final
# 0   70     88
# 1   88     12
# 2   58     65
# 3   39     87
# 4   46     88

# %%
df_2 = pd.DataFrame(np.random.randint(0,20, size=(5,2)), columns =['task1', 'task2'])

# %%
df_2
# Out:
#    task1  task2
# 0     17      5
# 1     13      8
# 2      9     19
# 3     16     19
# 4      5     15

# %%
pd.concat([df, df_2])
# Out:
#     mid  final  task1  task2
# 0  70.0   88.0    NaN    NaN
# 1  88.0   12.0    NaN    NaN
# 2  58.0   65.0    NaN    NaN
# 3  39.0   87.0    NaN    NaN
# 4  46.0   88.0    NaN    NaN
# 0   NaN    NaN   17.0    5.0
# 1   NaN    NaN   13.0    8.0
# 2   NaN    NaN    9.0   19.0
# 3   NaN    NaN   16.0   19.0
# 4   NaN    NaN    5.0   15.0

# %%
df_total = pd.concat([df, df_2], axis = 1)

# %%
df_total.mean()
# Out:
# mid      60.2
# final    68.0
# task1    12.0
# task2    13.2
# dtype: float64

# %%
df_total.mean(axis = 1)
# Out:
# 0    45.00
# 1    30.25
# 2    37.75
# 3    40.25
# 4    38.50
# dtype: float64
